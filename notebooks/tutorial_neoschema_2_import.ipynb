# %% [markdown]
# ## NeoSchema library - Tutorial 2 : set up a simple Schema (Classes, Properties)
# ## and perform a data import (Data Nodes)
#
# #### CAUTION: running this tutorial will clear out the database
#
# #### [Article](https://julianspolymathexplorations.blogspot.com/2022/11/schema-graph-databases-neo4j.html) to accompany this tutorial

# %%
import set_path      # Importing this module will add the project's home directory to sys.path
# Out:
# Added 'D:\Docs\- MY CODE\Brain Annex\BA-Win7' to sys.path

# %%
import os
import sys
import getpass
import pandas as pd

from neoaccess import NeoAccess
from BrainAnnex.modules.neo_schema.neo_schema import NeoSchema

# %% [markdown]
# # Connect to the database,
# #### using the `NeoAccess` library
# #### You can use a free local install of the Neo4j database, or a remote one on a virtual machine under your control, or a hosted solution, or simply the FREE "Sandbox" : [instructions here](https://julianspolymathexplorations.blogspot.com/2023/03/neo4j-sandbox-tutorial-cypher.html)
# NOTE: This tutorial is tested on version 4 of the Neo4j database, but will probably also work on the new version 5

# %%
# Save your credentials here (and skip the next cell!) - or use the prompts given by the next cell
host = ""
password = ""

# %%
db = NeoAccess(host=host,
               credentials=("neo4j", password), debug=False)   # Notice the debug option being OFF
# Out:
# Connection to Neo4j database established.

# %%
print("Version of the Neo4j driver: ", db.version())
# Out:
# Version of the Neo4j driver:  4.4.11

# %% [markdown]
# # Import of data from a Pandas data frame using the `NeoSchema` library

# %% [markdown]
# ### Initial setup

# %%
#db.empty_dbase()       # ******  WARNING: USE WITH CAUTION!!!  ******

# %%
NeoSchema.set_database(db)

# %% [markdown]
# ### Create the Schema

# %%
# Create an "Images" Class node - together with its Properties

NeoSchema.create_class_with_properties(name="Images", property_list=["uri", "basename", "suffix", "caption", "width", "height", "date_created"])
# Out:
# (20, 1)

# %%
df = pd.read_csv('D:\Docs\Brain Annex\- DATA TRANSFER IP\BA_1_i_images_old_neuro_notes.csv', encoding = "ISO-8859-1")
df
# Out:
#      uri            basename suffix  \
# 0   i-12   old-neuro-notes-1    jpg
# 1   i-13   old-neuro-notes-2    jpg
# 2   i-14   old-neuro-notes-3    jpg
# 3   i-15   old-neuro-notes-4    jpg
# 4   i-16   old-neuro-notes-5    jpg
# 5   i-17   old-neuro-notes-6    jpg
# 6   i-18   old-neuro-notes-7    jpg
# 7   i-19   old-neuro-notes-8    jpg
# 8   i-20   old-neuro-notes-9    jpg
# 9   i-21  old-neuro-notes-9b    jpg
# 10  i-22  old-neuro-notes-10    jpg
# 11  i-23  old-neuro-notes-11    jpg
# 12  i-24  old-neuro-notes-12    jpg
# 13  i-25  old-neuro-notes-13    jpg
# 14  i-26  old-neuro-notes-14    jpg
# 15  i-27  old-neuro-notes-15    jpg
# 16  i-28  old-neuro-notes-16    jpg
# 17  i-29  old-neuro-notes-17    jpg
# 18  i-30  old-neuro-notes-18    jpg
# 19  i-31  old-neuro-notes-19    jpg
# 20  i-32  old-neuro-notes-20    jpg
# 21  i-33  old-neuro-notes-21    jpg
# 22  i-34  old-neuro-notes-22    jpg
# 23  i-35  old-neuro-notes-23    jpg
# 24  i-36  old-neuro-notes-24    jpg
# 25  i-37  old-neuro-notes-25    jpg
# 26  i-38  old-neuro-notes-26    jpg
# 27  i-39  old-neuro-notes-27    jpg
# 28  i-40  old-neuro-notes-28    jpg
# 29  i-41  old-neuro-notes-29    jpg
# 30  i-42  old-neuro-notes-30    jpg
# 31  i-43  old-neuro-notes-31    jpg
# 32  i-44  old-neuro-notes-32    jpg
# 33  i-45  old-neuro-notes-33    jpg
# 34  i-46  old-neuro-notes-34    jpg
# 35  i-47  old-neuro-notes-35    jpg
# 36  i-48  old-neuro-notes-36    jpg
#
#                                            caption         date_created
# 0                                              NaN  2015-09-07 01:31:07
# 1                                              NaN  2015-09-07 01:41:32
# 2                                              NaN  2015-09-07 01:41:32
# 3                                              NaN  2015-09-07 02:00:23
# 4                                              NaN  2015-09-07 02:00:23
# 5                                              NaN  2015-09-07 02:01:24
# 6                                              NaN  2015-09-07 02:01:24
# 7                                              NaN  2015-09-07 02:01:24
# 8                                              NaN  2015-09-07 02:01:25
# 9                                              NaN  2015-09-07 02:01:25
# 10                                             NaN  2015-09-07 02:10:32
# 11                                             NaN  2015-09-07 02:10:32
# 12                                             NaN  2015-09-07 02:10:32
# 13                                             NaN  2015-09-07 02:10:32
# 14                            Facilitating Neurons  2015-09-07 02:10:32
# 15               Single-output vs. Multiple-Output  2015-09-07 02:10:33
# 16                                             NaN  2015-09-07 02:10:33
# 17                                             NaN  2015-09-07 02:10:33
# 18                                             NaN  2015-09-07 02:10:33
# 19                                  Logic Elements  2015-09-07 02:10:33
# 20                                 Memory Elements  2015-09-07 02:10:33
# 21                                             NaN  2015-09-07 02:10:33
# 22  Isolating pulse sequences of a given frequency  2015-09-07 02:10:33
# 23                             Asynchronous Inputs  2015-09-07 02:10:33
# 24                             Visualizing Signals  2015-09-07 02:10:33
# 25                                 Random Networks  2015-09-07 02:10:33
# 26                          Single-Neuron Networks  2015-09-07 02:10:33
# 27                                             NaN  2015-09-07 02:10:33
# 28                                             NaN  2015-09-07 02:10:34
# 29                                             NaN  2015-09-07 02:10:34
# 30                System with Associative Learning  2015-09-07 02:12:15
# 31                                             NaN  2015-09-07 02:12:15
# 32                                             NaN  2015-09-07 02:12:15
# 33                        Partition of Input Space  2015-09-07 02:12:15
# 34                                             NaN  2015-09-07 02:12:15
# 35                                             NaN  2015-09-07 02:12:15
# 36                                             NaN  2015-09-07 02:12:15

# %%
new_ids = NeoSchema.import_pandas_nodes(df=df, class_node="Images", extra_labels = "BA", schema_code="i", datetime_cols="date_created")
len(new_ids)
# Out:
# 37

# %%
df_2 = pd.read_csv('D:\Docs\Brain Annex\- DATA TRANSFER IP\BA_1_i_images.csv', encoding = "ISO-8859-1")
df_2
# Out:
#          uri                                           basename suffix  \
# 0        i-1                            1-Duck Capture Hot Keys    png
# 1       i-10                                              10-49    jpg
# 2      i-100                                     100-LunarPages    JPG
# 3     i-1000                                       1000-Blow-up    PNG
# 4     i-1001                  1001-y_predicted with a zeo value    PNG
# ...      ...                                                ...    ...
# 5263   i-994                     994-width 1 is a disaster zone    PNG
# 5264   i-995                 995-width 2 gives mediocre results    PNG
# 5265   i-996                   996-widths 3-100 all pretty good    PNG
# 5266   i-997    997-Different types of non-relational databases    png
# 5267   i-998  998-At the mercy of the initial conditions (ra...    PNG
#
#                                                 caption   width  height  \
# 0                                 Duck Capture Hot Keys     NaN     NaN
# 1     Use this with Outlook2007 & Gmail when non-Gma...     NaN     NaN
# 2                                            LunarPages     NaN     NaN
# 3     Blow-up, in spite of reasonable-sounding learn...   262.0   858.0
# 4     The root cause of the problem: y_predicted wit...   662.0   371.0
# ...                                                 ...     ...     ...
# 5263                         width 1 is a disaster zone  1269.0   622.0
# 5264                     width 2 gives mediocre results  1255.0   611.0
# 5265                       widths 3-100 all pretty good  1211.0  1015.0
# 5266  Different types of non-relational databases an...  1946.0  1020.0
# 5267  At the mercy of the initial conditions (random...  1829.0  1022.0
#
#              date_created
# 0     2015-07-10 00:00:00
# 1     2015-08-28 01:30:13
# 2     2016-08-03 00:00:31
# 3     2018-11-05 21:41:45
# 4     2018-11-05 21:41:46
# ...                   ...
# 5263  2018-11-03 21:42:48
# 5264  2018-11-03 21:42:48
# 5265  2018-11-03 21:42:53
# 5266  2018-11-05 12:22:40
# 5267  2018-11-05 21:35:44
#
# [5268 rows x 7 columns]

# %%
df_2_small = df_2[0:10]
df_2_small
# Out:
#       uri                                   basename suffix  \
# 0     i-1                    1-Duck Capture Hot Keys    png
# 1    i-10                                      10-49    jpg
# 2   i-100                             100-LunarPages    JPG
# 3  i-1000                               1000-Blow-up    PNG
# 4  i-1001          1001-y_predicted with a zeo value    PNG
# 5  i-1002            1002-Tiny corrective quantities    PNG
# 6  i-1004              1004-PICC server architecture    svg
# 7  i-1005                         1005-PICC workflow    svg
# 8  i-1006  1006-Exploring various initial conditions    PNG
# 9  i-1007                1007-Mediocre local minimum    PNG
#
#                                              caption   width  height  \
# 0                              Duck Capture Hot Keys     NaN     NaN
# 1  Use this with Outlook2007 & Gmail when non-Gma...     NaN     NaN
# 2                                         LunarPages     NaN     NaN
# 3  Blow-up, in spite of reasonable-sounding learn...   262.0   858.0
# 4  The root cause of the problem: y_predicted wit...   662.0   371.0
# 5                         Tiny corrective quantities  1262.0  1009.0
# 6                           PICC server architecture     NaN     NaN
# 7                                      PICC workflow     NaN     NaN
# 8               Exploring various initial conditions   156.0   303.0
# 9                             Mediocre local minimum  1250.0   614.0
#
#           date_created
# 0  2015-07-10 00:00:00
# 1  2015-08-28 01:30:13
# 2  2016-08-03 00:00:31
# 3  2018-11-05 21:41:45
# 4  2018-11-05 21:41:46
# 5  2018-11-05 21:41:48
# 6  2018-11-06 16:53:03
# 7  2018-11-06 22:33:22
# 8  2018-11-06 23:59:10
# 9  2018-11-06 23:59:12

# %%
new_ids_2 = NeoSchema.import_pandas_nodes(df=df_2, class_node="Images", extra_labels = "BA", schema_code="i", 
                                          datetime_cols="date_created", int_cols=["width", "height"])
len(new_ids_2)
# Out:
# 5268

# %%
df_rel = pd.read_csv('D:\Docs\Brain Annex\- DATA TRANSFER IP\BA_images_cat_.csv', encoding = "ISO-8859-1")
df_rel
# Out:
#      item_uri  old_ba_id  pos
# 0         i-1         54   20
# 1         i-2         52   30
# 2         i-3         80   20
# 3         i-4        100   10
# 4         i-6        107   20
# ...       ...        ...  ...
# 5478   i-6145       1055  -40
# 5479   i-6146       1055  -50
# 5480   i-6147       1085   20
# 5481   i-6148         67  308
# 5482   i-6149       1070   60
#
# [5483 rows x 3 columns]

# %%
NeoSchema.create_class_with_properties(name="Categories" , property_list=["name", "old_ba_id"])
# Out:
# (5316, 9)

# %%
NeoSchema.create_data_node(class_node="Categories", properties={'name': 'Duck Capture', 'old_ba_id': 54})
# Out:
# 5319

# %%
NeoSchema.create_data_node(class_node="Categories", properties={'name': 'RAID', 'old_ba_id': 52})
# Out:
# 5320

# %%
NeoSchema.create_data_node(class_node="Categories", properties={'name': 'Dreamweaver', 'old_ba_id': 80})
# Out:
# 5321

# %%
new_link = NeoSchema.import_pandas_links(df=df_rel, class_from="Images", class_to="Categories",
                             col_from="item_uri", col_to="old_ba_id",                            
                             link_name="BA_in_category", col_link_props="pos",
                             name_map={"item_uri": "uri"}, skip_errors=True)
# Out:
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-4', 'old_ba_id': 100, 'pos': 10}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-6', 'old_ba_id': 107, 'pos': 20}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-7', 'old_ba_id': 49, 'pos': 90}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-10', 'old_ba_id': 49, 'pos': 100}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-11', 'old_ba_id': 49, 'pos': 110}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-12', 'old_ba_id': 185, 'pos': 10}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-13', 'old_ba_id': 185, 'pos': 20}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-14', 'old_ba_id': 185, 'pos': 30}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-15', 'old_ba_id': 185, 'pos': 40}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-16', 'old_ba_id': 185, 'pos': 50}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-17', 'old_ba_id': 185, 'pos': 60}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-18', 'old_ba_id': 185, 'pos': 70}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-19', 'old_ba_id': 185, 'pos': 80}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-20', 'old_ba_id': 185, 'pos': 90}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-21', 'old_ba_id': 185, 'pos': 100}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-22', 'old_ba_id': 185, 'pos': 110}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-23', 'old_ba_id': 185, 'pos': 120}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-24', 'old_ba_id': 185, 'pos': 130}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-25', 'old_ba_id': 185, 'pos': 140}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-26', 'old_ba_id': 185, 'pos': 150}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-27', 'old_ba_id': 185, 'pos': 160}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-28', 'old_ba_id': 185, 'pos': 170}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-29', 'old_ba_id': 185, 'pos': 180}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-30', 'old_ba_id': 185, 'pos': 190}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-31', 'old_ba_id': 185, 'pos': 200}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-32', 'old_ba_id': 185, 'pos': 210}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-33', 'old_ba_id': 185, 'pos': 220}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-34', 'old_ba_id': 185, 'pos': 230}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-35', 'old_ba_id': 185, 'pos': 240}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-36', 'old_ba_id': 185, 'pos': 250}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-37', 'old_ba_id': 185, 'pos': 260}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-38', 'old_ba_id': 185, 'pos': 270}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-39', 'old_ba_id': 185, 'pos': 280}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-40', 'old_ba_id': 185, 'pos': 290}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-41', 'old_ba_id': 185, 'pos': 300}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-42', 'old_ba_id': 185, 'pos': 310}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-43', 'old_ba_id': 185, 'pos': 320}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-44', 'old_ba_id': 185, 'pos': 330}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-45', 'old_ba_id': 185, 'pos': 340}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-46', 'old_ba_id': 185, 'pos': 350}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-47', 'old_ba_id': 185, 'pos': 360}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-48', 'old_ba_id': 185, 'pos': 370}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-49', 'old_ba_id': 324, 'pos': 10}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-50', 'old_ba_id': 79, 'pos': 0}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i-51', 'old_ba_id': 324, 'pos': 20}
# import_pandas_links(): failed to create a new relationship for Pandas row: {'item_uri': 'i